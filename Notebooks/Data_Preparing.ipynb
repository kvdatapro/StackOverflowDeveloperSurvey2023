# %% [markdown]
# # Data Cleaning and Preparation

# %%
import io
import os
import glob
import re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.set_option("display.max_columns", 100)
directory_path = '../Datasets'

survey_results_path = f'{directory_path}/survey_results_public.csv'
schema_path = f'{directory_path}/survey_results_schema.csv'

survey_df = pd.read_csv(survey_results_path)
schema_df = pd.read_csv(schema_path)

# %% [markdown]
# ## Selecting the required columns from the dataframe
# #### 15 columns are used for the analysis.

# %%
selected_columns = ['Age', 'Employment', 'RemoteWork', 'CodingActivities', 'EdLevel', 
                    'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize', 'Country', 
                    'ConvertedCompYearly', 'LearnCodeCoursesCert', 'LanguageHaveWorkedWith', 
                    'DatabaseHaveWorkedWith','PlatformHaveWorkedWith']
survey_df = survey_df[selected_columns]

print(survey_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 89184 entries, 0 to 89183
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     89184 non-null  object
#  1   Employment              87898 non-null  object
#  2   RemoteWork              73810 non-null  object
#  3   CodingActivities        73764 non-null  object
#  4   EdLevel                 87973 non-null  object
#  5   YearsCode               87435 non-null  object
#  6   YearsCodePro            66136 non-null  object
#  7   DevType                 76872 non-null  object
#  8   OrgSize                 65043 non-null  object
#  9   Country                 87973 non-null  object
#  10  ConvertedCompYearly     48019 non-null  float64
#  11  LearnCodeCoursesCert    37076 non-null  object
#  12  LanguageHaveWorkedWith  87140 non-null  object
#  13  DatabaseHaveWorkedWith  73435 non-null  object
#  14  PlatformHaveWorkedWith  63628 non-null  object
# dtypes: float64(1), object(14)
# memory usage: 10.2+ MB
# None

# %% [markdown]
# ## Handling Missing Values

# %%
print("\nMissing Values: ")
print(survey_df.isnull().sum())
# Out:
# Missing Values:
# Age                           0
# Employment                 1286
# RemoteWork                15374
# CodingActivities          15420
# EdLevel                    1211
# YearsCode                  1749
# YearsCodePro              23048
# DevType                   12312
# OrgSize                   24141
# Country                    1211
# ConvertedCompYearly       41165
# LearnCodeCoursesCert      52108
# LanguageHaveWorkedWith     2044
# DatabaseHaveWorkedWith    15749
# PlatformHaveWorkedWith    25556
# dtype: int64

# %% [markdown]
# #### Different columns require different style of handling with missing values. Some critical columns like Yearly Compensation are required to be dropped whereas others like RemoteWork missing values can be replaced by "Not Specified" or "No Response".

# %%
clean_df = survey_df.dropna(subset=['ConvertedCompYearly','YearsCodePro','Country'])

# %%
clean_df = clean_df.assign(
    RemoteWork=clean_df['RemoteWork'].fillna('Not Specified'),
    Employment=clean_df['Employment'].fillna('Not Specified'),
    CodingActivities=clean_df['CodingActivities'].fillna('None'),
    EdLevel=clean_df['EdLevel'].fillna('Other'),
    OrgSize=clean_df['OrgSize'].fillna('Not Specified')
)


tech_columns = ['LanguageHaveWorkedWith', 'DatabaseHaveWorkedWith', 'PlatformHaveWorkedWith']
for i in tech_columns:
    clean_df[i].fillna('None', inplace=True)
print(clean_df.isnull().sum())
# Out:
# Age                           0
# Employment                    0
# RemoteWork                    0
# CodingActivities              0
# EdLevel                       0
# YearsCode                    25
# YearsCodePro                  0
# DevType                     102
# OrgSize                       0
# Country                       0
# ConvertedCompYearly           0
# LearnCodeCoursesCert      27149
# LanguageHaveWorkedWith        0
# DatabaseHaveWorkedWith        0
# PlatformHaveWorkedWith        0
# dtype: int64
# /var/folders/t9/dsx6mv5s7kl5ybn8ps1lw3q40000gn/T/ipykernel_15790/108167575.py:12: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   clean_df[i].fillna('None', inplace=True)

# %% [markdown]
# ## Converting Data Types

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47825 entries, 1 to 89171
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     47825 non-null  object
#  1   Employment              47825 non-null  object
#  2   RemoteWork              47825 non-null  object
#  3   CodingActivities        47825 non-null  object
#  4   EdLevel                 47825 non-null  object
#  5   YearsCode               47800 non-null  object
#  6   YearsCodePro            47825 non-null  object
#  7   DevType                 47723 non-null  object
#  8   OrgSize                 47825 non-null  object
#  9   Country                 47825 non-null  object
#  10  ConvertedCompYearly     47825 non-null  float64
#  11  LearnCodeCoursesCert    20676 non-null  object
#  12  LanguageHaveWorkedWith  47825 non-null  object
#  13  DatabaseHaveWorkedWith  47825 non-null  object
#  14  PlatformHaveWorkedWith  47825 non-null  object
# dtypes: float64(1), object(14)
# memory usage: 5.8+ MB

# %%
clean_df['YearsCode'] = pd.to_numeric(clean_df['YearsCode'], errors='coerce')
clean_df['YearsCodePro'] = pd.to_numeric(clean_df['YearsCodePro'], errors='coerce')
clean_df['ConvertedCompYearly'] = pd.to_numeric(clean_df['ConvertedCompYearly'], errors='coerce')

clean_df['YearsCodePro'] = clean_df['YearsCodePro'].fillna(clean_df['YearsCodePro'].median())
clean_df['YearsCode'] = clean_df['YearsCode'].fillna(clean_df['YearsCode'].median())

clean_df['DevType'] = clean_df['DevType'].fillna('Not Specified')

clean_df['LearnCodeCoursesCert'] = clean_df['LearnCodeCoursesCert'].fillna('None')

# %%
print(clean_df.isnull().sum())
# Out:
# Age                       0
# Employment                0
# RemoteWork                0
# CodingActivities          0
# EdLevel                   0
# YearsCode                 0
# YearsCodePro              0
# DevType                   0
# OrgSize                   0
# Country                   0
# ConvertedCompYearly       0
# LearnCodeCoursesCert      0
# LanguageHaveWorkedWith    0
# DatabaseHaveWorkedWith    0
# PlatformHaveWorkedWith    0
# dtype: int64

# %%
clean_df.info()
clean_df.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47825 entries, 1 to 89171
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     47825 non-null  object
#  1   Employment              47825 non-null  object
#  2   RemoteWork              47825 non-null  object
#  3   CodingActivities        47825 non-null  object
#  4   EdLevel                 47825 non-null  object
#  5   YearsCode               47825 non-null  float64
#  6   YearsCodePro            47825 non-null  float64
#  7   DevType                 47825 non-null  object
#  8   OrgSize                 47825 non-null  object
#  9   Country                 47825 non-null  object
#  10  ConvertedCompYearly     47825 non-null  float64
#  11  LearnCodeCoursesCert    47825 non-null  object
#  12  LanguageHaveWorkedWith  47825 non-null  object
#  13  DatabaseHaveWorkedWith  47825 non-null  object
#  14  PlatformHaveWorkedWith  47825 non-null  object
# dtypes: float64(3), object(12)
# memory usage: 5.8+ MB
#                 Age                                         Employment  \
# 1   25-34 years old                                Employed, full-time
# 2   45-54 years old                                Employed, full-time
# 3   25-34 years old                                Employed, full-time
# 4   25-34 years old  Employed, full-time;Independent contractor, fr...
# 5   35-44 years old                                Employed, full-time
# 6   35-44 years old                                Employed, full-time
# 7   25-34 years old                                Employed, full-time
# 8   45-54 years old                                Employed, full-time
# 11  25-34 years old                                Employed, full-time
# 12  25-34 years old                                Employed, full-time
#
#                               RemoteWork  \
# 1                                 Remote
# 2   Hybrid (some remote, some in-person)
# 3   Hybrid (some remote, some in-person)
# 4                                 Remote
# 5                                 Remote
# 6                                 Remote
# 7                                 Remote
# 8   Hybrid (some remote, some in-person)
# 11                                Remote
# 12                                Remote
#
#                                      CodingActivities  \
# 1   Hobby;Contribute to open-source projects;Boots...
# 2   Hobby;Professional development or self-paced l...
# 3                                               Hobby
# 4   Hobby;Contribute to open-source projects;Profe...
# 5   Hobby;Professional development or self-paced l...
# 6   Hobby;Contribute to open-source projects;Profe...
# 7                                               Hobby
# 8            Hobby;Contribute to open-source projects
# 11                                              Hobby
# 12  Hobby;Professional development or self-paced l...
#
#                                               EdLevel  YearsCode  \
# 1        Bachelor’s degree (B.A., B.S., B.Eng., etc.)       18.0
# 2        Bachelor’s degree (B.A., B.S., B.Eng., etc.)       27.0
# 3        Bachelor’s degree (B.A., B.S., B.Eng., etc.)       12.0
# 4        Bachelor’s degree (B.A., B.S., B.Eng., etc.)        6.0
# 5   Some college/university study without earning ...       21.0
# 6   Some college/university study without earning ...        4.0
# 7        Bachelor’s degree (B.A., B.S., B.Eng., etc.)        5.0
# 8     Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       20.0
# 11       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       10.0
# 12       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       10.0
#
#     YearsCodePro                               DevType  \
# 1            9.0  Senior Executive (C-Suite, VP, etc.)
# 2           23.0                   Developer, back-end
# 3            7.0                  Developer, front-end
# 4            4.0                 Developer, full-stack
# 5           21.0                   Developer, back-end
# 6            3.0                 Developer, full-stack
# 7            3.0                 Developer, full-stack
# 8           15.0                  System administrator
# 11           9.0                 Developer, full-stack
# 12           9.0                 Developer, full-stack
#
#                      OrgSize  \
# 1           2 to 9 employees
# 2   5,000 to 9,999 employees
# 3       100 to 499 employees
# 4         20 to 99 employees
# 5       100 to 499 employees
# 6   1,000 to 4,999 employees
# 7         10 to 19 employees
# 8       100 to 499 employees
# 11      100 to 499 employees
# 12          2 to 9 employees
#
#                                               Country  ConvertedCompYearly  \
# 1                            United States of America             285000.0
# 2                            United States of America             250000.0
# 3                            United States of America             156000.0
# 4                                         Philippines              23456.0
# 5   United Kingdom of Great Britain and Northern I...              96828.0
# 6                            United States of America             135000.0
# 7                            United States of America              80000.0
# 8                                             Finland              64254.0
# 11                                          Australia              78003.0
# 12                           United States of America              75000.0
#
#     LearnCodeCoursesCert                             LanguageHaveWorkedWith  \
# 1                  Other                         HTML/CSS;JavaScript;Python
# 2                   None                         Bash/Shell (all shells);Go
# 3                   None  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 4   Other;Codecademy;edX                     HTML/CSS;JavaScript;TypeScript
# 5                  Other  Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 6                  Udemy  Ada;Clojure;Elixir;Go;HTML/CSS;Java;JavaScript...
# 7         Codecademy;edX  Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 8      Udemy;Pluralsight           C#;JavaScript;PowerShell;Ruby;TypeScript
# 11                  None  C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
# 12            Codecademy  Bash/Shell (all shells);Elixir;HTML/CSS;JavaSc...
#
#                                DatabaseHaveWorkedWith  \
# 1                                            Supabase
# 2                                                None
# 3                                    PostgreSQL;Redis
# 4           BigQuery;Elasticsearch;MongoDB;PostgreSQL
# 5           BigQuery;Cloud Firestore;PostgreSQL;Redis
# 6   MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 7                 Dynamodb;MongoDB;MySQL;Redis;SQLite
# 8   MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 11         Cosmos DB;Microsoft SQL Server;MySQL;Redis
# 12  BigQuery;Dynamodb;Elasticsearch;MongoDB;MySQL;...
#
#                                PlatformHaveWorkedWith
# 1            Amazon Web Services (AWS);Netlify;Vercel
# 2   Amazon Web Services (AWS);Google Cloud;OpenSta...
# 3                                   Cloudflare;Heroku
# 4   Amazon Web Services (AWS);Firebase;Heroku;Netl...
# 5   Amazon Web Services (AWS);Cloudflare;Google Cloud
# 6             Amazon Web Services (AWS);Digital Ocean
# 7     Amazon Web Services (AWS);Fly.io;Netlify;Vercel
# 8               Digital Ocean;Microsoft Azure;Netlify
# 11              Digital Ocean;Microsoft Azure;Netlify
# 12  Amazon Web Services (AWS);Digital Ocean;Fly.io...

# %%
clean_df.reset_index(drop=True, inplace=True)

# %%
clean_df.head(10)
# Out:
#                Age                                         Employment  \
# 0  25-34 years old                                Employed, full-time
# 1  45-54 years old                                Employed, full-time
# 2  25-34 years old                                Employed, full-time
# 3  25-34 years old  Employed, full-time;Independent contractor, fr...
# 4  35-44 years old                                Employed, full-time
# 5  35-44 years old                                Employed, full-time
# 6  25-34 years old                                Employed, full-time
# 7  45-54 years old                                Employed, full-time
# 8  25-34 years old                                Employed, full-time
# 9  25-34 years old                                Employed, full-time
#
#                              RemoteWork  \
# 0                                Remote
# 1  Hybrid (some remote, some in-person)
# 2  Hybrid (some remote, some in-person)
# 3                                Remote
# 4                                Remote
# 5                                Remote
# 6                                Remote
# 7  Hybrid (some remote, some in-person)
# 8                                Remote
# 9                                Remote
#
#                                     CodingActivities  \
# 0  Hobby;Contribute to open-source projects;Boots...
# 1  Hobby;Professional development or self-paced l...
# 2                                              Hobby
# 3  Hobby;Contribute to open-source projects;Profe...
# 4  Hobby;Professional development or self-paced l...
# 5  Hobby;Contribute to open-source projects;Profe...
# 6                                              Hobby
# 7           Hobby;Contribute to open-source projects
# 8                                              Hobby
# 9  Hobby;Professional development or self-paced l...
#
#                                              EdLevel  YearsCode  YearsCodePro  \
# 0       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       18.0           9.0
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       27.0          23.0
# 2       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       12.0           7.0
# 3       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        6.0           4.0
# 4  Some college/university study without earning ...       21.0          21.0
# 5  Some college/university study without earning ...        4.0           3.0
# 6       Bachelor’s degree (B.A., B.S., B.Eng., etc.)        5.0           3.0
# 7    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)       20.0          15.0
# 8       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       10.0           9.0
# 9       Bachelor’s degree (B.A., B.S., B.Eng., etc.)       10.0           9.0
#
#                                 DevType                   OrgSize  \
# 0  Senior Executive (C-Suite, VP, etc.)          2 to 9 employees
# 1                   Developer, back-end  5,000 to 9,999 employees
# 2                  Developer, front-end      100 to 499 employees
# 3                 Developer, full-stack        20 to 99 employees
# 4                   Developer, back-end      100 to 499 employees
# 5                 Developer, full-stack  1,000 to 4,999 employees
# 6                 Developer, full-stack        10 to 19 employees
# 7                  System administrator      100 to 499 employees
# 8                 Developer, full-stack      100 to 499 employees
# 9                 Developer, full-stack          2 to 9 employees
#
#                                              Country  ConvertedCompYearly  \
# 0                           United States of America             285000.0
# 1                           United States of America             250000.0
# 2                           United States of America             156000.0
# 3                                        Philippines              23456.0
# 4  United Kingdom of Great Britain and Northern I...              96828.0
# 5                           United States of America             135000.0
# 6                           United States of America              80000.0
# 7                                            Finland              64254.0
# 8                                          Australia              78003.0
# 9                           United States of America              75000.0
#
#    LearnCodeCoursesCert                             LanguageHaveWorkedWith  \
# 0                 Other                         HTML/CSS;JavaScript;Python
# 1                  None                         Bash/Shell (all shells);Go
# 2                  None  Bash/Shell (all shells);HTML/CSS;JavaScript;PH...
# 3  Other;Codecademy;edX                     HTML/CSS;JavaScript;TypeScript
# 4                 Other  Bash/Shell (all shells);HTML/CSS;JavaScript;Ru...
# 5                 Udemy  Ada;Clojure;Elixir;Go;HTML/CSS;Java;JavaScript...
# 6        Codecademy;edX  Go;HTML/CSS;JavaScript;Python;Rust;SQL;TypeScript
# 7     Udemy;Pluralsight           C#;JavaScript;PowerShell;Ruby;TypeScript
# 8                  None  C#;HTML/CSS;JavaScript;Kotlin;PowerShell;Pytho...
# 9            Codecademy  Bash/Shell (all shells);Elixir;HTML/CSS;JavaSc...
#
#                               DatabaseHaveWorkedWith  \
# 0                                           Supabase
# 1                                               None
# 2                                   PostgreSQL;Redis
# 3          BigQuery;Elasticsearch;MongoDB;PostgreSQL
# 4          BigQuery;Cloud Firestore;PostgreSQL;Redis
# 5  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 6                Dynamodb;MongoDB;MySQL;Redis;SQLite
# 7  MariaDB;Microsoft SQL Server;MySQL;PostgreSQL;...
# 8         Cosmos DB;Microsoft SQL Server;MySQL;Redis
# 9  BigQuery;Dynamodb;Elasticsearch;MongoDB;MySQL;...
#
#                               PlatformHaveWorkedWith
# 0           Amazon Web Services (AWS);Netlify;Vercel
# 1  Amazon Web Services (AWS);Google Cloud;OpenSta...
# 2                                  Cloudflare;Heroku
# 3  Amazon Web Services (AWS);Firebase;Heroku;Netl...
# 4  Amazon Web Services (AWS);Cloudflare;Google Cloud
# 5            Amazon Web Services (AWS);Digital Ocean
# 6    Amazon Web Services (AWS);Fly.io;Netlify;Vercel
# 7              Digital Ocean;Microsoft Azure;Netlify
# 8              Digital Ocean;Microsoft Azure;Netlify
# 9  Amazon Web Services (AWS);Digital Ocean;Fly.io...

# %%
cleanDP = '../Datasets/cleaned_survey_results10.csv'
clean_df.head(10).to_csv(cleanDP, index = False)
